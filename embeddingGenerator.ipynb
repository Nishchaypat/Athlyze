# %%
from google.cloud import aiplatform
import os

gemini = os.getenv("GEMINI_API_KEY")
location = os.getenv("location")
location_processor = os.getenv("location_processor")
project_id = os.getenv("project_id")
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]= 'preprocessing_credentials.json'

aiplatform.init(project=project_id, location=location)

# %%
import json
from vertexai.language_models import TextEmbeddingInput, TextEmbeddingModel

# Function to embed text using Vertex AI's Text Embedding Model
def embed_text_vertex(data):
    """
    Embeds text using Vertex AI's Text Embedding Model and updates the embeddings in the input data.
    Args:
        data (list): List of dictionaries containing 'text' and 'embedding'.
    Returns:
        list: Updated data with embeddings.
    """
    print("Starting embedding process...")

    # Initialize the embedding model
    model = TextEmbeddingModel.from_pretrained("textembedding-gecko@003")
    print("Embedding model initialized.")

    for entry in data:
        print(entry)
        text = entry['text']
        print(f"Embedding text for ID {entry['id']}...")

        try:
            # Generate embedding
            input_obj = TextEmbeddingInput(text=text)
            response = model.get_embeddings([input_obj])
            embedding = response[0].values

            # Update the entry with the embedding
            entry["embedding"] = embedding
            print(f"Successfully embedded text for ID {entry['id']}")
        except Exception as e:
            print(f"Error embedding text for ID {entry['id']}: {e}")
            entry["embedding"] = None

    print("Embedding process completed.")
    return data

# Main function
if __name__ == "__main__":
    # Path to the JSON file containing data
    input_file_path = "formatted_embeddings_input_nutrition.json"
    output_file_path = "embedded_results_nutrition.json"

    print(f"Loading data from {input_file_path}...")

    # Load the JSON file
    with open(input_file_path, "r") as input_file:
        data = json.load(input_file)
    
    print(f"Data loaded. Total entries: {len(data)}")

    # Embed the text data and update embeddings
    print("Embedding text data...")
    updated_data = embed_text_vertex(data)

    # Save the updated data with embeddings to a new JSON file
    with open(output_file_path, "w") as output_file:
        json.dump(updated_data, output_file, indent=4)

    print(f"Embedding process completed. Results saved to {output_file_path}.")
# Out:
# Loading data from formatted_embeddings_input_nutrition.json...
# Data loaded. Total entries: 4154
# Embedding text data...
# Starting embedding process...
# Embedding model initialized.
# {'id': 1, 'text': 'Weight loss differences between isocaloric high-carbohydrate and high-fat diets are generally small, but individual weight loss varies substantially within diet groups.', 'embedding': None}
# Embedding text for ID 1...
# Successfully embedded text for ID 1
# {'id': 2, 'text': 'Genotype patterns may modify diet effects, with carbohydrate-responsive genotypes potentially losing more weight on high-carbohydrate diets and fat-responsive genotypes potentially losing more weight on high-fat diets.', 'embedding': None}
# Embedding text for ID 2...
# Successfully embedded text for ID 2
# {'id': 3, 'text': 'A study involving 145 participants with overweight/obesity, identified as fat-responders or carbohydrate-responders based on their combined genotypes at ten genetic variants, found no significant difference in 12-week weight loss between genotype-concordant and genotype-discordant diets.', 'embedding': None}
# Embedding text for ID 3...
# Successfully embedded text for ID 3
# {'id': 4, 'text': 'The 2017–2018 National Health and Nutrition Examination Survey (NHANES) showed that almost 43% of US adults aged 20 and over have obesity, including 9.0% with severe obesity, and another 31% are overweight.', 'embedding': None}
# Embedding text for ID 4...
# Successfully embedded text for ID 4
# {'id': 5, 'text': 'Excess body fat increases the risk of numerous medical conditions and premature mortality.', 'embedding': None}
# Embedding text for ID 5...
# Successfully embedded text for ID 5
# {'id': 6, 'text': 'Retrospective data suggests that participants with carbohydrate-responsive polymorphisms lose more weight on high-carbohydrate diets and vice versa for those with fat-responsive polymorphisms, but these results have not been confirmed in randomized controlled trials.', 'embedding': None}
# Embedding text for ID 6...
# Successfully embedded text for ID 6
# {'id': 7, 'text': 'Studies attempting to determine low-fat and low-carbohydrate responsive genotypes based on single nucleotide polymorphisms (SNPs) from three genes (PPARG, ADRB2, and FABP2) have been criticized, and most genotype × diet interactions are not significant with rare replication.', 'embedding': None}
# Embedding text for ID 7...
# Successfully embedded text for ID 7
# {'id': 8, 'text': 'A more comprehensive risk score, comprised of a greater number of SNPs with demonstrated and validated effects on responses to high-fat/high-carbohydrate diets, may better define fat- and carbohydrate-responsive genetic predisposition scores.', 'embedding': None}
# Embedding text for ID 8...
# Successfully embedded text for ID 8
# {'id': 9, 'text': 'The study tested the hypothesis that participants assigned to a diet corresponding to their a priori-determined (fat-responsive or carbohydrate-responsive) genotype would lose more weight over 12 weeks than those assigned to a diet discordant with their genotype.', 'embedding': None}
# Embedding text for ID 9...
# Successfully embedded text for ID 9
# {'id': 10, 'text': 'The study aimed to analyze fat-responders and carbohydrate-responders separately, hypothesizing that fat-responders would lose more weight on a high-fat diet and carbohydrate-responders would lose more weight on a high-carbohydrate diet.', 'embedding': None}
# Embedding text for ID 10...
# Successfully embedded text for ID 10
# {'id': 11, 'text': 'The study also aimed to test a newly developed genetic risk score to determine fat- and carbohydrate-responsive genotypes based on the current state-of-the-art in nutrigenomics.', 'embedding': None}
# Embedding text for ID 11...
# Successfully embedded text for ID 11
# {'id': 12, 'text': 'The study aimed to determine associations between baseline insulin levels and homeostatic model assessment for insulin resistance (HOMA-IR) and differential weight loss between the diets.', 'embedding': None}
# Embedding text for ID 12...
# Successfully embedded text for ID 12
# {'id': 13, 'text': 'Some studies suggest that insulin resistance and glucose-stimulated insulin secretion influence differential weight loss between low-fat and low-carbohydrate diets, while others found no such interaction.', 'embedding': None}
# Embedding text for ID 13...
# Successfully embedded text for ID 13
# {'id': 14, 'text': 'Short-term weight loss is associated with long-term results.', 'embedding': None}
# Embedding text for ID 14...
# Successfully embedded text for ID 14
# {'id': 15, 'text': 'A 12-week intervention period generally has lower attrition rates compared to 6-month and 12-month programs.', 'embedding': None}
# Embedding text for ID 15...
# Successfully embedded text for ID 15
# {'id': 16, 'text': 'In this study, weight change did not differ significantly between genotype-concordant and genotype-discordant diets.', 'embedding': None}
# Embedding text for ID 16...
# Successfully embedded text for ID 16
# {'id': 17, 'text': 'Among fat-responders, weight change did not differ significantly between high-fat and high-carbohydrate diets.', 'embedding': None}
# Embedding text for ID 17...
# Successfully embedded text for ID 17
# {'id': 18, 'text': 'Among carbohydrate-responders, weight change did not differ significantly between high-carbohydrate and high-fat diets.', 'embedding': None}
# Embedding text for ID 18...
# Successfully embedded text for ID 18
# {'id': 19, 'text': 'Percent weight change and change in body fat did not differ significantly between genotype-concordant and genotype-discordant diets.', 'embedding': None}
# Embedding text for ID 19...
# Successfully embedded text for ID 19
# {'id': 20, 'text': 'Body fat percentage did not significantly differ between high-fat and high-carbohydrate diets.', 'embedding': None}
# Embedding text for ID 20...
# Successfully embedded text for ID 20
# {'id': 21, 'text': 'Among carbohydrate-responders, changes in weight and body fat percentage did not significantly differ between high-carbohydrate and high-fat diets.', 'embedding': None}
# Embedding text for ID 21...
# Successfully embedded text for ID 21
# {'id': 22, 'text': 'Changes in waist circumference, hip circumference, and waist-hip ratio did not differ between genotype-concordant and genotype-discordant diets.', 'embedding': None}
# Embedding text for ID 22...
# Successfully embedded text for ID 22
# {'id': 23, 'text': 'Changes in resting systolic and diastolic blood pressure did not differ between genotype-concordant and genotype-discordant diets.', 'embedding': None}
# Embedding text for ID 23...
# Successfully embedded text for ID 23
# {'id': 24, 'text': 'Changes in systolic and diastolic blood pressure did not differ between high-fat and high-carbohydrate diets among fat-responders.', 'embedding': None}
# Embedding text for ID 24...
# Successfully embedded text for ID 24
# {'id': 25, 'text': 'Changes in systolic and diastolic blood pressure did not differ between high-carbohydrate and high-fat diets among carbohydrate-responders.', 'embedding': None}
# Embedding text for ID 25...
# Successfully embedded text for ID 25
# {'id': 26, 'text': 'Baseline insulin levels and HOMA-IR were not associated with weight change.', 'embedding': None}
# Embedding text for ID 26...
# Successfully embedded text for ID 26
# {'id': 27, 'text': 'There was no significant interaction between diet and baseline HOMA-IR on weight change.', 'embedding': None}
# Embedding text for ID 27...
# Successfully embedded text for ID 27
# {'id': 28, 'text': 'Changes in food cravings did not differ between genotype-concordant and genotype-discordant diets.', 'embedding': None}
# Embedding text for ID 28...
# Successfully embedded text for ID 28
# {'id': 29, 'text': 'Among carbohydrate-responders, those on a high-fat diet decreased cravings for carbohydrates/starches relative to those on the high-carbohydrate diet.', 'embedding': None}
# Embedding text for ID 29...
# Successfully embedded text for ID 29
# {'id': 30, 'text': 'Individuals on a high-carbohydrate diet experienced a statistically significant reduction in cravings for carbohydrates/starches compared to those on a high-fat diet, with an adjusted difference of -0.7 (95% CI: -1.1, -0.4, p=0.006).', 'embedding': None}
# Embedding text for ID 30...
# Successfully embedded text for ID 30
# {'id': 31, 'text': 'Changes in food cravings, restraint, disinhibition, hunger, and food preferences did not differ between genotype-concordant and genotype-discordant diets.', 'embedding': None}
# Embedding text for ID 31...
# Successfully embedded text for ID 31
# {'id': 32, 'text': 'Diet preference and intervention satisfaction did not differ between genotype-concordant and genotype-discordant diets.', 'embedding': None}
# Embedding text for ID 32...
# Successfully embedded text for ID 32
# {'id': 33, 'text': 'Both genotype-concordant and genotype-discordant diets resulted in weight loss, with no significant difference in weight change between the two groups.', 'embedding': None}
# Embedding text for ID 33...
# Successfully embedded text for ID 33
# {'id': 34, 'text': 'Both high-fat and high-carbohydrate diets resulted in weight loss for fat-responders, with no significant difference in weight change between the two groups.', 'embedding': None}
# Embedding text for ID 34...
# Successfully embedded text for ID 34
# {'id': 35, 'text': 'For carbohydrate-responders, both high-carbohydrate and high-fat diets resulted in weight loss, with no significant difference in weight change between the two groups.', 'embedding': None}
# Embedding text for ID 35...
# Successfully embedded text for ID 35
# {'id': 36, 'text': 'There were no significant differences in changes in waist circumference, hip circumference, or waist-hip ratio between genotype-concordant and genotype-discordant diets.', 'embedding': None}
# Embedding text for ID 36...
# Successfully embedded text for ID 36
# {'id': 37, 'text': 'There were no significant differences in changes in waist circumference, hip circumference, or waist-hip ratio between high-fat and high-carbohydrate diets for fat-responders.', 'embedding': None}
# Embedding text for ID 37...
# Successfully embedded text for ID 37
# {'id': 38, 'text': 'There were no significant differences in changes in waist circumference, hip circumference, or waist-hip ratio between high-carbohydrate and high-fat diets for carbohydrate-responders.', 'embedding': None}
# Embedding text for ID 38...
# Successfully embedded text for ID 38
# {'id': 39, 'text': 'Systolic blood pressure (SBP) showed a significant increase in fat-responders on the high-fat diet compared to the high-carbohydrate diet, with an adjusted difference of 6.9 mmHg (95% CI: 2.0, 11.8).', 'embedding': None}
# Embedding text for ID 39...
# Successfully embedded text for ID 39
# {'id': 40, 'text': 'There was no significant difference in diastolic blood pressure (DBP) changes between the different diet groups.', 'embedding': None}
# Embedding text for ID 40...
# Successfully embedded text for ID 40
# {'id': 41, 'text': 'Participants on the high-carbohydrate diet consumed approximately 63% of their energy from carbohydrates, 20% from fat, and 16% from protein across weeks 4, 8, and 12, closely aligning with their target macronutrient ratios.', 'embedding': None}
# Embedding text for ID 41...
# Successfully embedded text for ID 41
# {'id': 42, 'text': 'Participants on the high-fat diet consumed approximately 45% of their energy from carbohydrates, 40% from fat, and 16% from protein across weeks 4, 8, and 12, also closely aligning with their target macronutrient ratios.', 'embedding': None}
# Embedding text for ID 42...
# Successfully embedded text for ID 42
# {'id': 43, 'text': 'Weekly session attendance ranged from 85% to 100% across all genotype-diet groups.', 'embedding': None}
# Embedding text for ID 43...
# Successfully embedded text for ID 43
# {'id': 44, 'text': 'There was no significant difference in weight loss between individuals on genotype-concordant diets versus genotype-discordant diets over 12 weeks.', 'embedding': None}
# Embedding text for ID 44...
# Successfully embedded text for ID 44
# {'id': 45, 'text': 'Insulin levels or HOMA-IR were not associated with weight loss in this study.', 'embedding': None}
# Embedding text for ID 45...
# Successfully embedded text for ID 45
# {'id': 46, 'text': 'Food cravings tended to decrease among carbohydrate-responders on a high-fat diet compared to those on a high-carbohydrate diet.', 'embedding': None}
# Embedding text for ID 46...
# Successfully embedded text for ID 46
# {'id': 47, 'text': 'Fat-responders on a high-carbohydrate diet tended to experience a decrease in resting systolic blood pressure (SBP).', 'embedding': None}
# Embedding text for ID 47...
# Successfully embedded text for ID 47
# {'id': 48, 'text': 'The study determined fat- or carbohydrate-responsive genotypes based on an algorithm involving 10 SNPs, contrasting with a previous study that used 3 SNPs.', 'embedding': None}
# Embedding text for ID 48...
# Successfully embedded text for ID 48
# {'id': 49, 'text': "The study's findings, supported by a meta-analysis, suggest that with current genotyping abilities, there is no evidence that genotype-concordant diets result in greater weight loss.", 'embedding': None}
# Embedding text for ID 49...
# Successfully embedded text for ID 49
# {'id': 50, 'text': 'The study sample had substantially fewer carbohydrate-responders (n=37) than fat-responders (n=85), reflecting the prevalence in the population.', 'embedding': None}
# Embedding text for ID 50...
# Successfully embedded text for ID 50
# {'id': 51, 'text': 'Approximately 39% of individuals in the study were classified as responsive to both or neither of the two diets (high-fat and high-carbohydrate), 41% were fat-responders, and 20% were carbohydrate-responders.', 'embedding': None}
# Embedding text for ID 51...
# Successfully embedded text for ID 51
# {'id': 52, 'text': 'The distribution of responders to different diets was different from the initial estimates, suggesting a need for larger studies to verify if this uneven distribution is representative of the general population.', 'embedding': None}
# Embedding text for ID 52...
# Successfully embedded text for ID 52
# {'id': 53, 'text': 'A low-carbohydrate diet without energy intake target has previously shown greater improvements in body composition, blood lipids, and estimated 10-year coronary heart disease risk compared to a low-fat diet.', 'embedding': None}
# Embedding text for ID 53...
# Successfully embedded text for ID 53
# {'id': 54, 'text': 'Fasting insulin levels and HOMA-IR did not predict weight loss (WL) in this study.', 'embedding': None}
# Embedding text for ID 54...
# Successfully embedded text for ID 54
# {'id': 55, 'text': 'Previous studies suggest that lower-carbohydrate diets are superior for individuals with greater insulin resistance and high baseline insulin secretion.', 'embedding': None}
# Embedding text for ID 55...
# Successfully embedded text for ID 55
# {'id': 56, 'text': 'The influence of insulin sensitivity and insulin secretion on weight loss via a low-fat vs. a low-carbohydrate diet is inconsistent across studies.', 'embedding': None}
# Embedding text for ID 56...
# Successfully embedded text for ID 56
# {'id': 57, 'text': 'Weight loss can reduce food cravings, particularly for foods restricted on specific diets.', 'embedding': None}
# Embedding text for ID 57...
# Successfully embedded text for ID 57
# {'id': 58, 'text': 'Among carbohydrate-responders, cravings tended to decrease for high-carbohydrate foods on the high-fat diet, and cravings also decreased modestly for high-fat foods.', 'embedding': None}
# Embedding text for ID 58...
# Successfully embedded text for ID 58
# {'id': 59, 'text': 'Among fat-responders, a high-carbohydrate diet tended to decrease resting systolic blood pressure (SBP), although this could be partially explained by regression to the mean.', 'embedding': None}
# Embedding text for ID 59...
# Successfully embedded text for ID 59
# {'id': 60, 'text': 'All genotype-diet groups had relatively well-controlled blood pressure, limiting the potential for significant improvements through dietary changes.', 'embedding': None}
# Embedding text for ID 60...
# Successfully embedded text for ID 60
# {'id': 61, 'text': 'Weight loss (WL) is influenced by multiple modifiable and non-modifiable factors, including genetics, and current knowledge only accounts for a small percentage of the variability.', 'embedding': None}
# Embedding text for ID 61...
# Successfully embedded text for ID 61
# {'id': 62, 'text': "Genotypes may influence participants' weight loss responses in directions different from those predicted from measured genotypes.", 'embedding': None}
# Embedding text for ID 62...
# Successfully embedded text for ID 62
# {'id': 63, 'text': 'More comprehensive knowledge of the role of genetics in weight loss is needed, potentially from genome-wide association studies.', 'embedding': None}
# Embedding text for ID 63...
# Successfully embedded text for ID 63
# {'id': 64, 'text': 'A longer timeframe (6-12 months) may increase the amount and differential weight loss between diets.', 'embedding': None}
# Embedding text for ID 64...
# Successfully embedded text for ID 64
# {'id': 65, 'text': 'A larger sample size might allow for detecting differences in clinically important secondary outcomes such as changes in body fat.', 'embedding': None}
# Embedding text for ID 65...
# Successfully embedded text for ID 65
# {'id': 66, 'text': 'Dietary adherence can be affected when meals are not provided in a study.', 'embedding': None}
# Embedding text for ID 66...
# Successfully embedded text for ID 66
# {'id': 67, 'text': "Future studies should assess the macronutrient composition of participants' habitual diets to see any differences in the magnitude of the shifts from baseline to the high-fat or high-carbohydrate diet.", 'embedding': None}
# Embedding text for ID 67...
# Successfully embedded text for ID 67
# {'id': 68, 'text': 'Using an oral glucose tolerance test (AUC or INS-30) rather than HOMA-IR to quantify insulin resistance might be a better option, as HOMA-IR has limited sensitivity.', 'embedding': None}
# Embedding text for ID 68...
# Successfully embedded text for ID 68
# {'id': 69, 'text': 'HOMA-IR does not reflect differences between tissues (e.g., adipose, muscle) or postprandial physiology.', 'embedding': None}
# Embedding text for ID 69...
# Successfully embedded text for ID 69
# {'id': 70, 'text': 'Non-fasting methods yield greater variability of the glucose/insulin dynamics and may be more suitable for assessing insulin resistance.', 'embedding': None}
# Embedding text for ID 70...
# Successfully embedded text for ID 70
# {'id': 71, 'text': 'Bioelectrical impedance analysis (BIA) does not provide information on body fat distribution.', 'embedding': None}
# Embedding text for ID 71...
# Successfully embedded text for ID 71
# {'id': 72, 'text': 'Participation in nutrigenomics studies generally induces improved diet adherence, independent of the specific recommendations.', 'embedding': None}
# Embedding text for ID 72...
# Successfully embedded text for ID 72
# {'id': 73, 'text': 'The Personalized Nutrition Study (POINTS) was a 12-week, single-site, parallel-arm weight loss (WL) trial.', 'embedding': None}
# Embedding text for ID 73...
# Successfully embedded text for ID 73
# {'id': 74, 'text': 'Participants were identified a priori as carbohydrate-responders or fat-responders based on their genotype.', 'embedding': None}
# Embedding text for ID 74...
# Successfully embedded text for ID 74
# {'id': 75, 'text': 'The study investigated the impact of genotype-concordant and genotype-discordant diets on food cravings.', 'embedding': None}
# Embedding text for ID 75...
# Successfully embedded text for ID 75
# {'id': 76, 'text': 'The study measured changes in cravings for high fats, sweets, carbohydrates/starches, fast-food fats, fruits and vegetables, and total cravings.', 'embedding': None}
# Embedding text for ID 76...
# Successfully embedded text for ID 76
# {'id': 77, 'text': 'The study was approved by the institutional review board (IRB FWA 00006218) of the Pennington Biomedical Research Center (PBRC, Baton Rouge, LA).', 'embedding': None}
# Embedding text for ID 77...
# Successfully embedded text for ID 77
# {'id': 78, 'text': 'Participants were enrolled between October 7, 2020 and September 8, 2021.', 'embedding': None}
# Embedding text for ID 78...
# Successfully embedded text for ID 78
# {'id': 79, 'text': 'Participants were categorized as either carbohydrate-responders or fat-responders based on their genotypes at 10 specific genetic loci.', 'embedding': None}
# Embedding text for ID 79...
# Successfully embedded text for ID 79
# {'id': 80, 'text': 'The study involved four groups: fat-responders on a high-fat diet, fat-responders on a high-carbohydrate diet, carbohydrate-responders on a high-fat diet, and carbohydrate-responders on a high-carbohydrate diet.', 'embedding': None}
# Embedding text for ID 80...
# Successfully embedded text for ID 80
# {'id': 81, 'text': 'Eligible participants were between 18 and 75 years old with a BMI between 27.0 and 47.5 kg/m^2, and had completed or were willing to complete a genealogy test and share the raw data.', 'embedding': None}
# Embedding text for ID 81...
# Successfully embedded text for ID 81
# {'id': 82, 'text': 'Participants were excluded if they smoked, had a weight change of 10 lbs or more in the last 3 months, were pregnant or breastfeeding, had conditions or medications affecting body weight or metabolism, or had a genotype indicating a predisposition to respond favorably to neither or both diets.', 'embedding': None}
# Embedding text for ID 82...
# Successfully embedded text for ID 82
# {'id': 83, 'text': 'The genetic variants used to determine carbohydrate or fat response included: FGF21rs838147, TCF7L2rs12255372, IRS1rs2943641, APOA5rs662799, PLIN1rs894160, APOA2rs5082, FTOrs9939609, PPARGrs1801282, GIPRrs10423928, and GYS2rs1478290.', 'embedding': None}
# Embedding text for ID 83...
# Successfully embedded text for ID 83
# {'id': 84, 'text': 'The study included 1 orientation visit, 2 clinic visits (one before and one after the intervention), and 12 weekly intervention sessions.', 'embedding': None}
# Embedding text for ID 84...
# Successfully embedded text for ID 84
# {'id': 85, 'text': 'The study investigated the effects of high-carbohydrate and high-fat diets on individuals, with the high-carbohydrate diet consisting of approximately 20% energy from fat and 65% from carbohydrates, while the high-fat diet consisted of approximately 40% energy from fat and 45% from carbohydrates. Both diets provided 15% of energy from protein.', 'embedding': None}
# Embedding text for ID 85...
# Successfully embedded text for ID 85
# {'id': 86, 'text': 'Participants were assigned a daily energy deficit of approximately 750 kcal and provided with meal plans ranging from 1400 to 2800 kcal/day in 200 kcal increments.', 'embedding': None}
# Embedding text for ID 86...
# Successfully embedded text for ID 86
# {'id': 87, 'text': 'The meal plans included a list of ingredients and instructions for meal preparation, and participants were provided with a food scale to facilitate adherence.', 'embedding': None}
# Embedding text for ID 87...
# Successfully embedded text for ID 87
# {'id': 88, 'text': 'Baseline energy requirements were calculated using the Mifflin-St. Jeor formula.', 'embedding': None}
# Embedding text for ID 88...
# Successfully embedded text for ID 88
# {'id': 89, 'text': 'The study utilized a risk score comprising 10 SNPs (single nucleotide polymorphisms) with demonstrated effects on responses to high-fat/high-carbohydrate diets.', 'embedding': None}
# Embedding text for ID 89...
# Successfully embedded text for ID 89
# {'id': 90, 'text': 'The study used a Food Preference Questionnaire (FPQ) to assess dietary preferences and responses to different macronutrient compositions (high fat/high simple sugar, low fat/high simple sugar, high fat/high complex carbohydrate, low fat/high complex carbohydrate, high fat/low carbohydrate/high protein, low fat/low carbohydrate/high protein).', 'embedding': None}
# Embedding text for ID 90...
# Successfully embedded text for ID 90
# {'id': 91, 'text': 'The study included participants who were classified as either fat-responders or carbohydrate-responders based on their genetic predisposition.', 'embedding': None}
# Embedding text for ID 91...
# Successfully embedded text for ID 91
# {'id': 92, 'text': 'A 1:1 randomization scheme was used to ensure a relatively equal baseline BMI between the 4 genotype-diet groups, adjusting for BMI, gender, and genotype.', 'embedding': None}
# Embedding text for ID 92...
# Successfully embedded text for ID 92
# {'id': 93, 'text': 'Gender and genotype were used as strata in the randomization process, while BMI was used in an a-priori-created randomization equation.', 'embedding': None}
# Embedding text for ID 93...
# Successfully embedded text for ID 93
# {'id': 94, 'text': 'Block sizes of 6 (for females) and 4 (for males) were used at the start of the study, ending with block sizes of 4 and 2, respectively, to ensure relative balance of group assignments.', 'embedding': None}
# Embedding text for ID 94...
# Successfully embedded text for ID 94
# {'id': 95, 'text': 'Outcome assessors were blind to diet assignment and genotype patterns.', 'embedding': None}
# Embedding text for ID 95...
# Successfully embedded text for ID 95
# {'id': 96, 'text': 'Interventionists were blind to genotype patterns but not diet type.', 'embedding': None}
# Embedding text for ID 96...
# Successfully embedded text for ID 96
# {'id': 97, 'text': 'Participants were only informed of their genotype (carbohydrate- or fat-responder) after completing the study.', 'embedding': None}
# Embedding text for ID 97...
# Successfully embedded text for ID 97
# {'id': 98, 'text': 'Participants were provided a body weight scale and encouraged to weigh daily throughout the intervention.', 'embedding': None}
# Embedding text for ID 98...
# Successfully embedded text for ID 98
# {'id': 99, 'text': 'Fasting body weight and waist and hip circumference were measured at baseline (W0) and at 12 weeks (W12).', 'embedding': None}
# Embedding text for ID 99...
# Successfully embedded text for ID 99
# {'id': 100, 'text': 'Body fat percentage was measured via bioelectrical impedance.', 'embedding': None}
# Embedding text for ID 100...
# Successfully embedded text for ID 100
# {'id': 101, 'text': 'Body fat percentage was measured using bioelectrical impedance analysis (BIA).', 'embedding': None}
# Embedding text for ID 101...
# Successfully embedded text for ID 101
# {'id': 102, 'text': 'Fasting serum glucose and insulin levels were measured to quantify insulin resistance using HOMA-IR.', 'embedding': None}
# Embedding text for ID 102...
# Successfully embedded text for ID 102
# {'id': 103, 'text': 'Appetitive traits, food cravings, and food preferences were assessed using the Eating Inventory (EI), Food Craving Inventory (FCI), and Food Preference Questionnaire (FPQ), respectively.', 'embedding': None}
# Embedding text for ID 103...
# Successfully embedded text for ID 103
# {'id': 104, 'text': 'Participants were provided with kitchen scales to precisely weigh all ingredients in their meal plans, and additional foods consumed were also weighed.', 'embedding': None}
# Embedding text for ID 104...
# Successfully embedded text for ID 104
# {'id': 105, 'text': 'Adherence to macronutrient content of assigned diets was assessed for three 7-day periods throughout the intervention.', 'embedding': None}
# Embedding text for ID 105...
# Successfully embedded text for ID 105
# {'id': 106, 'text': 'Linear mixed models were used to determine if changes in outcome variables differed among diets, accounting for the correlation of the subject over time.', 'embedding': None}
# Embedding text for ID 106...
# Successfully embedded text for ID 106
# {'id': 107, 'text': 'The primary outcome was weight change (kg) at 12 weeks, while all other measures were secondary endpoints.', 'embedding': None}
# Embedding text for ID 107...
# Successfully embedded text for ID 107
# {'id': 108, 'text': 'The study investigated the effects of high-carbohydrate and high-fat diets on weight loss in individuals categorized as either carbohydrate-responders or fat-responders.', 'embedding': None}
# Embedding text for ID 108...
# Successfully embedded text for ID 108
# {'id': 109, 'text': 'The high-carbohydrate diet group aimed for 65% carbohydrates, 20% fat, and 15% protein, while the high-fat diet group targeted 45% carbohydrates, 40% fat, and 15% protein.', 'embedding': None}
# Embedding text for ID 109...
# Successfully embedded text for ID 109
# {'id': 110, 'text': 'The study had a statistical power of 80% to detect a 2.0 kg difference in weight change between specific diet groups and >95% power to test if weight loss differs between participants on a genotype-concordant diet and those on a genotype-discordant diet.', 'embedding': None}
# Embedding text for ID 110...
# Successfully embedded text for ID 110
# {'id': 111, 'text': 'Baseline insulin levels and HOMA-IR were not significantly associated with weight loss in this study and were not included as covariates in the analysis.', 'embedding': None}
# Embedding text for ID 111...
# Successfully embedded text for ID 111
# {'id': 112, 'text': 'The study used a linear mixed model, adjusted for diet group and other known covariates, to test the effects of baseline insulin levels and HOMA-IR on weight loss.', 'embedding': None}
# Embedding text for ID 112...
# Successfully embedded text for ID 112
# {'id': 113, 'text': 'Weight loss can be achieved through various dietary approaches, including low-carbohydrate, Mediterranean, and low-fat diets.', 'embedding': None}
# Embedding text for ID 113...
# Successfully embedded text for ID 113
# {'id': 114, 'text': "The effectiveness of different macronutrient compositions on weight loss can be influenced by an individual's insulin sensitivity.", 'embedding': None}
# Embedding text for ID 114...
# Successfully embedded text for ID 114
# {'id': 115, 'text': "Adherence to low-fat vs. low-carbohydrate diets may differ based on an individual's insulin resistance status.", 'embedding': None}
# Embedding text for ID 115...
# Successfully embedded text for ID 115
# {'id': 116, 'text': 'A low-glycemic load diet may be more effective for weight loss in overweight adults with high insulin secretion compared to those with low insulin secretion.', 'embedding': None}
# Embedding text for ID 116...
# Successfully embedded text for ID 116
# {'id': 117, 'text': "Genetic factors can play a role in predicting weight loss success, suggesting that the 'right' diet may vary between individuals.", 'embedding': None}
# Embedding text for ID 117...
# Successfully embedded text for ID 117
# {'id': 118, 'text': 'Initial weight loss response in the first 2 months of a lifestyle intervention can predict weight changes years later.', 'embedding': None}
# Embedding text for ID 118...
# Successfully embedded text for ID 118
# {'id': 119, 'text': 'Low-carbohydrate and low-fat diets have different effects on the body.', 'embedding': None}
# Embedding text for ID 119...
# Successfully embedded text for ID 119
# {'id': 120, 'text': 'A low-glycemic load diet was compared to a low-fat diet in obese young adults.', 'embedding': None}
# Embedding text for ID 120...
# Successfully embedded text for ID 120
# {'id': 121, 'text': 'Weight loss on low-fat vs. low-carbohydrate diets is influenced by insulin resistance status.', 'embedding': None}
# Embedding text for ID 121...
# Successfully embedded text for ID 121
# {'id': 122, 'text': 'Food cravings, food preferences, and appetite change during low-carbohydrate and low-fat diets.', 'embedding': None}
# Embedding text for ID 122...
# Successfully embedded text for ID 122
# {'id': 123, 'text': 'Food cravings can be a conditioned response related to body weight.', 'embedding': None}
# Embedding text for ID 123...
# Successfully embedded text for ID 123
# {'id': 124, 'text': 'Macronutrient intake-associated FGF21 genotype modifies the effects of weight-loss diets on changes in central adiposity and body composition.', 'embedding': None}
# Embedding text for ID 124...
# Successfully embedded text for ID 124
# {'id': 125, 'text': "TCF7L2 rs7903146 interacts with macronutrients in obese individuals' responses to a hypoenergetic diet.", 'embedding': None}
# Embedding text for ID 125...
# Successfully embedded text for ID 125
# {'id': 126, 'text': 'Perilipin polymorphism interacts with dietary carbohydrates to modulate anthropometric traits.', 'embedding': None}
# Embedding text for ID 126...
# Successfully embedded text for ID 126
# {'id': 127, 'text': 'Insulin receptor substrate 1 gene variation modifies insulin resistance response to weight-loss diets.', 'embedding': None}
# Embedding text for ID 127...
# Successfully embedded text for ID 127
# {'id': 128, 'text': 'APOA2, dietary fat, and body mass index show a gene-diet interaction.', 'embedding': None}
# Embedding text for ID 128...
# Successfully embedded text for ID 128
# {'id': 129, 'text': 'APOA5 gene variation interacts with dietary fat intake to modulate obesity and circulating triglycerides.', 'embedding': None}
# Embedding text for ID 129...
# Successfully embedded text for ID 129
# {'id': 130, 'text': 'Dietary fat intake interacts with APOA2, APOA5, and LEPR polymorphisms in relation to obesity and dyslipidemia.', 'embedding': None}
# Embedding text for ID 130...
# Successfully embedded text for ID 130
# {'id': 131, 'text': 'Polymorphism PLIN1 11482 G>A interacts with dietary intake to modulate anthropometric measures and lipid profile in adults with normal-weight obesity syndrome.', 'embedding': None}
# Embedding text for ID 131...
# Successfully embedded text for ID 131
# {'id': 132, 'text': 'The APOA2 promoter polymorphism is associated with body weight, showing a gene-saturated fat interaction.', 'embedding': None}
# Embedding text for ID 132...
# Successfully embedded text for ID 132
# {'id': 133, 'text': 'The rs9939609 gene variant in FTO modifies the metabolic response of weight loss after a hypocaloric diet.', 'embedding': None}
# Embedding text for ID 133...
# Successfully embedded text for ID 133
# {'id': 134, 'text': 'FTO genotype influences weight loss in diet and lifestyle interventions.', 'embedding': None}
# Embedding text for ID 134...
# Successfully embedded text for ID 134
# {'id': 135, 'text': 'PPARγPro12Ala interacts with fat intake for obesity and weight loss in a Mediterranean diet-based behavioral treatment.', 'embedding': None}
# Embedding text for ID 135...
# Successfully embedded text for ID 135
# {'id': 136, 'text': 'Weight-loss diets modify glucose-dependent insulinotropic polypeptide receptor rs2287019 genotype effects on changes in body weight, fasting glucose, and insulin resistance.', 'embedding': None}
# Embedding text for ID 136...
# Successfully embedded text for ID 136
# {'id': 137, 'text': 'Physiogenomic comparison of human fat loss in response to diets restrictive of carbohydrate or fat has been studied.', 'embedding': None}
# Embedding text for ID 137...
# Successfully embedded text for ID 137
# {'id': 138, 'text': 'Disclosure of genetic information can influence changes in dietary intake.', 'embedding': None}
# Embedding text for ID 138...
# Successfully embedded text for ID 138
# {'id': 139, 'text': 'Personalizing nutritional guidance can lead to more effective behavior change.', 'embedding': None}
# Embedding text for ID 139...
# Successfully embedded text for ID 139
# {'id': 140, 'text': 'Genetic information can be used to personalize a calorie-controlled diet for improved weight management.', 'embedding': None}
# Embedding text for ID 140...
# Successfully embedded text for ID 140
# {'id': 141, 'text': 'TCF7L2 genetic variants modulate the effect of dietary fat intake on changes in body composition during a weight-loss intervention.', 'embedding': None}
# Embedding text for ID 141...
# Successfully embedded text for ID 141
# {'id': 142, 'text': 'APOA5 gene variation modulates the effects of dietary fat intake on body mass index and obesity risk.', 'embedding': None}
# Embedding text for ID 142...
# Successfully embedded text for ID 142
# {'id': 143, 'text': 'A new predictive equation for resting energy expenditure in healthy individuals was developed.', 'embedding': None}
# Embedding text for ID 143...
# Successfully embedded text for ID 143
# {'id': 144, 'text': 'The three-factor eating questionnaire measures dietary restraint, disinhibition, and hunger.', 'embedding': None}
# Embedding text for ID 144...
# Successfully embedded text for ID 144
# {'id': 145, 'text': 'The reliability and validity of a macronutrient self-selection paradigm and a food preference questionnaire have been assessed.', 'embedding': None}
# Embedding text for ID 145...
# Successfully embedded text for ID 145
# {'id': 146, 'text': 'Smartphone-based weight loss interventions have shown efficacy.', 'embedding': None}
# Embedding text for ID 146...
# Successfully embedded text for ID 146
# {'id': 147, 'text': 'Calorie restriction can affect biomarkers of longevity, metabolic adaptation, and oxidative stress in overweight individuals.', 'embedding': None}
# Embedding text for ID 147...
# Successfully embedded text for ID 147
# {'id': 148, 'text': 'Sufficient physical activity and a healthy diet are known to substantially contribute to the prevention of chronic diseases and obesity.', 'embedding': None}
# Embedding text for ID 148...
# Successfully embedded text for ID 148
# {'id': 149, 'text': "General dietary and physical activity guidelines are often 'one size fits all' and disregard differences between individuals in terms of biology, behavior, genetics, and the sociopsychological environment.", 'embedding': None}
# Embedding text for ID 149...
# Successfully embedded text for ID 149
# {'id': 150, 'text': 'Personalized approaches may be more effective in changing lifestyle parameters such as diet, sleep, stress, and physical activity.', 'embedding': None}
# Embedding text for ID 150...
# Successfully embedded text for ID 150
# {'id': 151, 'text': 'The overall goal of personalized nutrition approaches is to promote or maintain the health status of an individual by using personal data to tailor dietary recommendations or services to fit their specific needs.', 'embedding': None}
# Embedding text for ID 151...
# Successfully embedded text for ID 151
# {'id': 152, 'text': 'Personalized nutrition approaches can be more effective in improving dietary behavior compared to generic information.', 'embedding': None}
# Embedding text for ID 152...
# Successfully embedded text for ID 152
# {'id': 153, 'text': 'Individuals may show a differential physiological response to nutrients, foods, or dietary patterns.', 'embedding': None}
# Embedding text for ID 153...
# Successfully embedded text for ID 153
# {'id': 154, 'text': "Personalized nutrition advice can be tailored to an individual's constitution and preferences, making it more effective than generic advice.", 'embedding': None}
# Embedding text for ID 154...
# Successfully embedded text for ID 154
# {'id': 155, 'text': 'Information perceived as more relevant by an individual is more likely to receive attention, increasing its impact.', 'embedding': None}
# Embedding text for ID 155...
# Successfully embedded text for ID 155
# {'id': 156, 'text': 'Personalized advice can range from focusing on a single nutrient to complex systems including multiple measurements and recommendations.', 'embedding': None}
# Embedding text for ID 156...
# Successfully embedded text for ID 156
# {'id': 157, 'text': 'Personalized nutrition advice can be delivered through various methods, including coaching, meal services, and digital platforms.', 'embedding': None}
# Embedding text for ID 157...
# Successfully embedded text for ID 157
# {'id': 158, 'text': 'Digital personalized nutrition advice systems (PNASs) typically consist of a sensing part (input parameters), a reasoning part (translating input into advice), and an acting part (communicating advice).', 'embedding': None}
# Embedding text for ID 158...
# Successfully embedded text for ID 158
# {'id': 159, 'text': 'PNASs operate in a feedback loop where users provide personal information, which is then processed to generate personalized advice, and finally communicated back to the user.', 'embedding': None}
# Embedding text for ID 159...
# Successfully embedded text for ID 159
# {'id': 160, 'text': 'The physical dimension of health encompasses a broad scope, ranging from the absence of disease to the level of physical fitness.', 'embedding': None}
# Embedding text for ID 160...
# Successfully embedded text for ID 160
# {'id': 161, 'text': 'Classical physical health is often determined by the phenotype, which is assessed by benchmarking anthropometric measurements and single overnight fasting plasma biomarkers against cutoff values.', 'embedding': None}
# Embedding text for ID 161...
# Successfully embedded text for ID 161
# {'id': 162, 'text': 'Health is currently considered as the body’s ability to adapt to changing circumstances while remaining within homeostatic boundaries.', 'embedding': None}
# Embedding text for ID 162...
# Successfully embedded text for ID 162
# {'id': 163, 'text': 'Personalized Nutrition and Activity Systems (PNAS) can utilize a wide variety of input parameters, including clinical measures, behavior, well-being, genetics, and personal preferences.', 'embedding': None}
# Embedding text for ID 163...
# Successfully embedded text for ID 163
# {'id': 164, 'text': 'Relevant data for personalization can be categorized into biological characteristics and data related to current behavior, preferences, barriers, and objectives.', 'embedding': None}
# Embedding text for ID 164...
# Successfully embedded text for ID 164
# {'id': 165, 'text': 'Integrating multiple measured biomarkers or phenotypic traits is key for assessing health status, as relying on single measurements like fasting glucose may overlook subtle changes.', 'embedding': None}
# Embedding text for ID 165...
# Successfully embedded text for ID 165
# {'id': 166, 'text': 'A health space model can be used to combine multiple biomarkers into a single score using multivariate statistical methods and reference population data.', 'embedding': None}
# Embedding text for ID 166...
# Successfully embedded text for ID 166
# {'id': 167, 'text': "Phenotypic health parameters such as sex, age, anthropometrics, plasma biochemical markers, vitals, and genotypic data can be used to represent a person's health status.", 'embedding': None}
# Embedding text for ID 167...
# Successfully embedded text for ID 167
# {'id': 168, 'text': 'Measurements for health assessment should be accurate, valid, and relatively easy to obtain.', 'embedding': None}
# Embedding text for ID 168...
# Successfully embedded text for ID 168
# {'id': 169, 'text': 'Basic characteristics like age and sex can be combined with anthropometrics and vitals such as body weight, blood pressure, body length, and waist circumference for health assessment.', 'embedding': None}
# Embedding text for ID 169...
# Successfully embedded text for ID 169
# {'id': 170, 'text': 'More extensive anthropometric measurements (e.g., fat percentage) and blood samples for plasma biomarkers (e.g., HDL, LDL cholesterol, glucose, triglycerides) can be collected when participants are easily accessible.', 'embedding': None}
# Embedding text for ID 170...
# Successfully embedded text for ID 170
# {'id': 171, 'text': 'In settings with limited access, do-it-yourself measurements like body weight scales, blood pressure meters, and handheld devices for plasma biomarkers can be used.', 'embedding': None}
# Embedding text for ID 171...
# Successfully embedded text for ID 171
# {'id': 172, 'text': 'Lifestyle factors such as food intake, physical exercise, stress, physical environment, and social support networks influence health status in addition to physical health parameters.', 'embedding': None}
# Embedding text for ID 172...
# Successfully embedded text for ID 172
# {'id': 173, 'text': "Knowledge about an individual's current lifestyle adds value to personalized advice because health parameters alone may not cover all required aspects and the relationships between lifestyle and health are not fully understood.", 'embedding': None}
# Embedding text for ID 173...
# Successfully embedded text for ID 173
# {'id': 174, 'text': 'Current lifestyle behavior can serve as a proxy for health status.', 'embedding': None}
# Embedding text for ID 174...
# Successfully embedded text for ID 174
# {'id': 175, 'text': 'Integrating current lifestyle behavior into personalized advice could increase the relevance of recommendations to match individuals’ current behavior, habits, and preferences.', 'embedding': None}
# Embedding text for ID 175...
# Successfully embedded text for ID 175
# {'id': 176, 'text': 'Two main approaches for measuring lifestyle behavior are monitoring (using sensors and mobile apps) and self-reporting (using questionnaires).', 'embedding': None}
# Embedding text for ID 176...
# Successfully embedded text for ID 176
# {'id': 177, 'text': 'Self-reporting methods for dietary intake include food frequency questionnaires, food diaries/dietary recalls, and healthy eating indexes.', 'embedding': None}
# Embedding text for ID 177...
# Successfully embedded text for ID 177
# {'id': 178, 'text': 'Conventional tools for measuring dietary behavior are subject to overreporting and underreporting.', 'embedding': None}
# Embedding text for ID 178...
# Successfully embedded text for ID 178
# {'id': 179, 'text': 'Nutrient profiling in blood (plasma levels of specific vitamins, minerals, or metabolites) can be considered as a proxy for dietary status.', 'embedding': None}
# Embedding text for ID 179...
# Successfully embedded text for ID 179
# {'id': 180, 'text': 'Biomarkers like alkylresorcinols (for whole grain intake), lipid profiling (for fish intake), and combinations of carotenoids and vitamins (for fruit and vegetable intake) can reflect dietary intake on a food-group level.', 'embedding': None}
# Embedding text for ID 180...
# Successfully embedded text for ID 180
# {'id': 181, 'text': 'Most biomarker levels reflect long-term dietary behavior rather than short-term food intake.', 'embedding': None}
# Embedding text for ID 181...
# Successfully embedded text for ID 181
# {'id': 182, 'text': 'Combining biomarkers with classical approaches like food diaries and questionnaires may result in a more accurate assessment of dietary intake.', 'embedding': None}
# Embedding text for ID 182...
# Successfully embedded text for ID 182
# {'id': 183, 'text': 'Diet quality indexes assess adherence to specific dietary patterns based on population-based dietary guidelines.', 'embedding': None}
# Embedding text for ID 183...
# Successfully embedded text for ID 183
# {'id': 184, 'text': 'The Dutch Healthy Eating Index (DHEI) questionnaire includes 15 food groups and provides an overall diet quality score.', 'embedding': None}
# Embedding text for ID 184...
# Successfully embedded text for ID 184
# {'id': 185, 'text': 'Focusing on food groups for dietary advice is more consistent with the shift in Dutch dietary guidelines from single nutrients to food groups.', 'embedding': None}
# Embedding text for ID 185...
# Successfully embedded text for ID 185
# {'id': 186, 'text': 'Evidence-based relations between both food groups and health parameters, and nutrients and health parameters, can be incorporated into dietary advice systems.', 'embedding': None}
# Embedding text for ID 186...
# Successfully embedded text for ID 186
# {'id': 187, 'text': "Dietary advice based on food groups is easier for consumers to apply as they don't need to identify specific nutrients in foods.", 'embedding': None}
# Embedding text for ID 187...
# Successfully embedded text for ID 187
# {'id': 188, 'text': 'The DHEI (Dietary Health Index) does not provide information on the consumption of specific food products or the amount of macronutrients and micronutrients consumed.', 'embedding': None}
# Embedding text for ID 188...
# Successfully embedded text for ID 188
# {'id': 189, 'text': 'The DHEI provides output on a qualitative level, not quantitative, and does not provide insight into the exact amount of vegetables consumed (in grams).', 'embedding': None}
# Embedding text for ID 189...
# Successfully embedded text for ID 189
# ...
# Embedding text for ID 4082...
# Successfully embedded text for ID 4082
# {'id': 4083, 'text': 'Computer-tailored interventions can be effective for health behavior change, including diet and physical activity.', 'embedding': None}
# Embedding text for ID 4083...
# Successfully embedded text for ID 4083
# {'id': 4084, 'text': 'Personalized nutrition approaches can benefit health and function.', 'embedding': None}
# Embedding text for ID 4084...
# Successfully embedded text for ID 4084
# {'id': 4085, 'text': 'Systems biology is relevant to personalized nutrition.', 'embedding': None}
# Embedding text for ID 4085...
# Successfully embedded text for ID 4085
# {'id': 4086, 'text': 'Behavioral treatment strategies can improve adherence to lifestyle intervention programs in adults with obesity.', 'embedding': None}
# Embedding text for ID 4086...
# Successfully embedded text for ID 4086
# {'id': 4087, 'text': 'Reducing sedentary behavior in the workplace can positively impact cardiometabolic risk markers.', 'embedding': None}
# Embedding text for ID 4087...
# Successfully embedded text for ID 4087
# {'id': 4088, 'text': 'Technology-driven interventions are being used for type 2 diabetes prevention.', 'embedding': None}
# Embedding text for ID 4088...
# Successfully embedded text for ID 4088
# {'id': 4089, 'text': 'Web-based interventions can target cardiovascular risk factors in middle-aged and older people.', 'embedding': None}
# Embedding text for ID 4089...
# Successfully embedded text for ID 4089
# {'id': 4090, 'text': 'Maintaining behavior change after physical activity and dietary interventions is a challenge.', 'embedding': None}
# Embedding text for ID 4090...
# Successfully embedded text for ID 4090
# {'id': 4091, 'text': 'The internet can be used to promote health behavior change.', 'embedding': None}
# Embedding text for ID 4091...
# Successfully embedded text for ID 4091
# {'id': 4092, 'text': 'Theoretical basis and behavior change techniques influence the efficacy of internet-based health interventions.', 'embedding': None}
# Embedding text for ID 4092...
# Successfully embedded text for ID 4092
# {'id': 4093, 'text': 'Brief telephone support may improve engagement with web-based weight management interventions.', 'embedding': None}
# Embedding text for ID 4093...
# Successfully embedded text for ID 4093
# {'id': 4094, 'text': 'Intrapersonal variation exists in goal setting and achievement in health coaching.', 'embedding': None}
# Embedding text for ID 4094...
# Successfully embedded text for ID 4094
# {'id': 4095, 'text': "Implementation intentions to change one's diet work best when tailored to personally relevant reasons for unhealthy eating.", 'embedding': None}
# Embedding text for ID 4095...
# Successfully embedded text for ID 4095
# {'id': 4096, 'text': 'The number and specificity of implementation intentions matter in increasing physical activity.', 'embedding': None}
# Embedding text for ID 4096...
# Successfully embedded text for ID 4096
# {'id': 4097, 'text': 'Phenotypic flexibility is a key factor in the human nutrition and health relationship.', 'embedding': None}
# Embedding text for ID 4097...
# Successfully embedded text for ID 4097
# {'id': 4098, 'text': 'Fat oxidation before and after a high fat load differs in the obese insulin-resistant state.', 'embedding': None}
# Embedding text for ID 4098...
# Successfully embedded text for ID 4098
# {'id': 4099, 'text': 'Challenging homeostasis can help define biomarkers for nutrition-related health.', 'embedding': None}
# Embedding text for ID 4099...
# Successfully embedded text for ID 4099
# {'id': 4100, 'text': 'Phenotypic flexibility can be used as a measure of health, specifically through the optimal nutritional stress response test.', 'embedding': None}
# Embedding text for ID 4100...
# Successfully embedded text for ID 4100
# {'id': 4101, 'text': 'Quantifying phenotypic flexibility can be done by assessing the response to a high-fat challenge test in different states of metabolic health.', 'embedding': None}
# Embedding text for ID 4101...
# Successfully embedded text for ID 4101
# {'id': 4102, 'text': 'Whole grain wheat consumption affects postprandial inflammatory response in overweight and obese adults with mild hypercholesterolemia.', 'embedding': None}
# Embedding text for ID 4102...
# Successfully embedded text for ID 4102
# {'id': 4103, 'text': 'Visualization and identification of health space can be based on personalized molecular phenotype and treatment response to relevant underlying biological processes.', 'embedding': None}
# Embedding text for ID 4103...
# Successfully embedded text for ID 4103
# {'id': 4104, 'text': 'Ranges of phenotypic flexibility can be observed in healthy subjects.', 'embedding': None}
# Embedding text for ID 4104...
# Successfully embedded text for ID 4104
# {'id': 4105, 'text': 'Genetic variations, such as in the FTO gene, can influence the relationship between dietary intake (specifically fat and carbohydrate) and obesity.', 'embedding': None}
# Embedding text for ID 4105...
# Successfully embedded text for ID 4105
# {'id': 4106, 'text': 'High-protein/low-carbohydrate diets can have different effects on weight and cardiovascular risk factors depending on genetic variations, such as the rs9939609 FTO gene variant.', 'embedding': None}
# Embedding text for ID 4106...
# Successfully embedded text for ID 4106
# {'id': 4107, 'text': 'Dietary protein intake can interact with FTO genotype to affect appetite.', 'embedding': None}
# Embedding text for ID 4107...
# Successfully embedded text for ID 4107
# {'id': 4108, 'text': 'A new predictive equation for resting energy expenditure in healthy individuals was developed.', 'embedding': None}
# Embedding text for ID 4108...
# Successfully embedded text for ID 4108
# {'id': 4109, 'text': 'Energy imbalance directly affects body weight.', 'embedding': None}
# Embedding text for ID 4109...
# Successfully embedded text for ID 4109
# {'id': 4110, 'text': 'Riboflavin can lower blood pressure in cardiovascular disease patients who are homozygous for the 677C>T polymorphism in the MTHFR gene.', 'embedding': None}
# Embedding text for ID 4110...
# Successfully embedded text for ID 4110
# {'id': 4111, 'text': 'Riboflavin intervention can be a targeted approach for managing hypertension in individuals with the MTHFR 677TT genotype.', 'embedding': None}
# Embedding text for ID 4111...
# Successfully embedded text for ID 4111
# {'id': 4112, 'text': 'EPA, DHA, and DPA are related to the maintenance of normal blood pressure and HDL-cholesterol concentrations.', 'embedding': None}
# Embedding text for ID 4112...
# Successfully embedded text for ID 4112
# {'id': 4113, 'text': 'Motivational interviewing can be effective for weight loss among adults in primary care.', 'embedding': None}
# Embedding text for ID 4113...
# Successfully embedded text for ID 4113
# {'id': 4114, 'text': 'Motivational interviewing can be used for weight loss among adults in primary care.', 'embedding': None}
# Embedding text for ID 4114...
# Successfully embedded text for ID 4114
# {'id': 4115, 'text': 'Goal-setting is important for weight-gain prevention, especially in college populations.', 'embedding': None}
# Embedding text for ID 4115...
# Successfully embedded text for ID 4115
# {'id': 4116, 'text': 'Appetitive traits are related to BMI in adults.', 'embedding': None}
# Embedding text for ID 4116...
# Successfully embedded text for ID 4116
# {'id': 4117, 'text': 'Hematocrit and punch location can affect assay bias during quantitative bioanalysis of dried blood spot samples.', 'embedding': None}
# Embedding text for ID 4117...
# Successfully embedded text for ID 4117
# {'id': 4118, 'text': 'The concentration of low-density lipoprotein cholesterol in plasma can be estimated without using an ultracentrifuge.', 'embedding': None}
# Embedding text for ID 4118...
# Successfully embedded text for ID 4118
# {'id': 4119, 'text': 'Homeostasis Model Assessment (HOMA) can be used to assess insulin resistance and β-cell function from fasting plasma glucose and insulin concentrations.', 'embedding': None}
# Embedding text for ID 4119...
# Successfully embedded text for ID 4119
# {'id': 4120, 'text': 'A 12-week whole-grain wheat intervention can protect against hepatic fat in overweight subjects.', 'embedding': None}
# Embedding text for ID 4120...
# Successfully embedded text for ID 4120
# {'id': 4121, 'text': 'Increasing fruit and vegetable intake through dietary intervention can affect nutritional biomarkers and attitudes to dietary change.', 'embedding': None}
# Embedding text for ID 4121...
# Successfully embedded text for ID 4121
# {'id': 4122, 'text': 'Fruit and vegetable consumption is associated with higher vitamin intake and blood vitamin status among European adolescents.', 'embedding': None}
# Embedding text for ID 4122...
# Successfully embedded text for ID 4122
# {'id': 4123, 'text': 'Resting heart rate is associated with health-related physical fitness in Brazilian adolescents.', 'embedding': None}
# Embedding text for ID 4123...
# Successfully embedded text for ID 4123
# {'id': 4124, 'text': 'Aerobic training intensity affects resting, exercise, and post-exercise blood pressure, heart rate, and heart-rate variability.', 'embedding': None}
# Embedding text for ID 4124...
# Successfully embedded text for ID 4124
# {'id': 4125, 'text': 'Elevated resting heart rate is associated with increased all-cause mortality.', 'embedding': None}
# Embedding text for ID 4125...
# Successfully embedded text for ID 4125
# {'id': 4126, 'text': 'Long-term lifestyle programs can impact weight loss and cardiovascular risk factors in overweight/obese individuals.', 'embedding': None}
# Embedding text for ID 4126...
# Successfully embedded text for ID 4126
# {'id': 4127, 'text': 'Intermittent energy restriction and continuous energy restriction have been studied for their effects on weight loss and cardiometabolic outcomes.', 'embedding': None}
# Embedding text for ID 4127...
# Successfully embedded text for ID 4127
# {'id': 4128, 'text': 'Exercise training and hypocaloric diets have distinct effects on body weight and visceral adipose tissue.', 'embedding': None}
# Embedding text for ID 4128...
# Successfully embedded text for ID 4128
# {'id': 4129, 'text': 'High-protein, partial meal replacement programs, with or without alternate day fasting, can lead to similar weight loss, retention, nutritional, metabolic, and behavioral outcomes.', 'embedding': None}
# Embedding text for ID 4129...
# Successfully embedded text for ID 4129
# {'id': 4130, 'text': 'Weight loss maintenance can be influenced by the protein content and glycemic index of ad libitum diets.', 'embedding': None}
# Embedding text for ID 4130...
# Successfully embedded text for ID 4130
# {'id': 4131, 'text': 'Energy-restricted high-protein, low-fat diets have been compared to standard-protein, low-fat diets for their effects on weight loss.', 'embedding': None}
# Embedding text for ID 4131...
# Successfully embedded text for ID 4131
# {'id': 4132, 'text': 'Dietary strategies play a role in weight loss maintenance.', 'embedding': None}
# Embedding text for ID 4132...
# Successfully embedded text for ID 4132
# {'id': 4133, 'text': 'Protein intake is important for weight loss and maintenance.', 'embedding': None}
# Embedding text for ID 4133...
# Successfully embedded text for ID 4133
# {'id': 4134, 'text': 'Protein plays a significant role in food intake and body weight regulation.', 'embedding': None}
# Embedding text for ID 4134...
# Successfully embedded text for ID 4134
# {'id': 4135, 'text': 'Long-term low-fat and high-fat diets have different effects on blood lipid levels in overweight or obese patients.', 'embedding': None}
# Embedding text for ID 4135...
# Successfully embedded text for ID 4135
# {'id': 4136, 'text': 'Replacing saturated fats with unsaturated fats can have beneficial effects on lipid biomarkers, E-selectin, and blood pressure, but may not impact vascular function.', 'embedding': None}
# Embedding text for ID 4136...
# Successfully embedded text for ID 4136
# {'id': 4137, 'text': 'Low-fat and high-fat diets have different effects on cardiometabolic indicators.', 'embedding': None}
# Embedding text for ID 4137...
# Successfully embedded text for ID 4137
# {'id': 4138, 'text': 'Low-fat diets have been compared to high-fat diets in their effects on cardiometabolic indicators in overweight and obese individuals without overt metabolic disturbance.', 'embedding': None}
# Embedding text for ID 4138...
# Successfully embedded text for ID 4138
# {'id': 4139, 'text': 'The field of personalized nutrition is being explored through nutrigenetics and nutrigenomics.', 'embedding': None}
# Embedding text for ID 4139...
# Successfully embedded text for ID 4139
# {'id': 4140, 'text': 'Nutrigenomics-guided lifestyle interventions have shown potential for enhanced long-term dietary change and adherence compared to population-based interventions for weight management.', 'embedding': None}
# Embedding text for ID 4140...
# Successfully embedded text for ID 4140
# {'id': 4141, 'text': 'Disclosure of genetic information can influence changes in dietary intake.', 'embedding': None}
# Embedding text for ID 4141...
# Successfully embedded text for ID 4141
# {'id': 4142, 'text': 'Individualized dietary advice, supplemented with walnuts, has been studied for its effect on blood pressure.', 'embedding': None}
# Embedding text for ID 4142...
# Successfully embedded text for ID 4142
# {'id': 4143, 'text': 'Personalized nutrition has been investigated for its impact on health-related behavior change.', 'embedding': None}
# Embedding text for ID 4143...
# Successfully embedded text for ID 4143
# {'id': 4144, 'text': 'Communicating genetic risks of disease can impact risk-reducing health behavior.', 'embedding': None}
# Embedding text for ID 4144...
# Successfully embedded text for ID 4144
# {'id': 4145, 'text': 'Incorporating genetic testing results into nutrition counseling and care has been analyzed for its effect on dietary intake and health outcomes.', 'embedding': None}
# Embedding text for ID 4145...
# Successfully embedded text for ID 4145
# {'id': 4146, 'text': 'Barriers and enablers for adopting lifestyle behavior changes in adolescents with obesity have been studied.', 'embedding': None}
# Embedding text for ID 4146...
# Successfully embedded text for ID 4146
# {'id': 4147, 'text': 'Determinants of lifestyle behavior change to prevent type 2 diabetes in high-risk individuals have been investigated.', 'embedding': None}
# Embedding text for ID 4147...
# Successfully embedded text for ID 4147
# {'id': 4148, 'text': 'Health coaching has been explored as a method to improve healthy lifestyle behaviors.', 'embedding': None}
# Embedding text for ID 4148...
# Successfully embedded text for ID 4148
# {'id': 4149, 'text': 'Bioelectrical Impedance Analysis has limitations and needs validation when used on morbidly obese patients.', 'embedding': None}
# Embedding text for ID 4149...
# Successfully embedded text for ID 4149
# {'id': 4150, 'text': 'Workplace interventions can be effective in promoting healthy eating habits.', 'embedding': None}
# Embedding text for ID 4150...
# Successfully embedded text for ID 4150
# {'id': 4151, 'text': 'Worksite health promotion programs can influence changes in eating behavior and health attitudes.', 'embedding': None}
# Embedding text for ID 4151...
# Successfully embedded text for ID 4151
# {'id': 4152, 'text': 'Participation in workplace health programs can be measured using a participation index, which is associated with health risk change.', 'embedding': None}
# Embedding text for ID 4152...
# Successfully embedded text for ID 4152
# {'id': 4153, 'text': 'Human postprandial responses to food vary, suggesting the potential for precision nutrition.', 'embedding': None}
# Embedding text for ID 4153...
# Successfully embedded text for ID 4153
# {'id': 4154, 'text': 'A standardized mixed meal tolerance test can be used to compare metabolic responses in healthy and type 2 diabetic subjects.', 'embedding': None}
# Embedding text for ID 4154...
# Successfully embedded text for ID 4154
# Embedding process completed.
# Embedding process completed. Results saved to embedded_results_nutrition.json.

# %% [markdown]
# Old Method:

# %%
import json
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from vertexai.language_models import TextEmbeddingInput, TextEmbeddingModel

# Function to clean data
def clean_data(data):
    """
    Cleans the text data by removing duplicates, very basic text, and normalizing content.
    Args:
        data (list): List of text rows.
    Returns:
        list: Cleaned text rows.
    """
    print("Starting data cleaning...")
    
    # Convert list to DataFrame
    df = pd.DataFrame(data, columns=["text"])
    print(f"Initial data loaded. Total entries: {len(df)}")
    
    # Remove duplicates
    df = df.drop_duplicates(subset=["text"])
    print(f"Removed duplicates. Remaining entries: {len(df)}")
    
    # Remove short or basic text (less than 5 words or very generic)
    df = df[df["text"].apply(lambda x: len(x.split()) > 5)]
    print(f"Removed short/basic text. Remaining entries: {len(df)}")
    
    # Normalize text: remove special characters, extra spaces
    df["text"] = df["text"].str.replace(r"[^\w\s]", "", regex=True).str.strip()
    print("Normalized text.")
    
    # Optional: Remove highly similar rows using cosine similarity
    print("Calculating cosine similarity for identifying similar rows...")
    tfidf = TfidfVectorizer()
    tfidf_matrix = tfidf.fit_transform(df["text"])
    similarity_matrix = cosine_similarity(tfidf_matrix)
    
    # Identify rows with high similarity
    to_remove = set()
    for i in range(len(similarity_matrix)):
        for j in range(i + 1, len(similarity_matrix)):
            if similarity_matrix[i, j] > 0.9:  # Threshold for similarity
                to_remove.add(j)
    
    print(f"Identified {len(to_remove)} similar rows to remove.")
    
    # Keep only unique rows
    df = df.iloc[list(set(range(len(df))) - to_remove)]
    print(f"Final cleaned data. Remaining entries: {len(df)}")
    
    return df["text"].tolist()

# Function to embed text using Vertex AI's Text Embedding Model
def embed_text_vertex(cleaned_text):
    """
    Embeds text using Vertex AI's Text Embedding Model.
    Args:
        cleaned_text (list): List of cleaned text rows.
    Returns:
        pd.DataFrame: DataFrame with original text and embeddings.
    """
    print("Starting embedding process...")

    # Initialize the embedding model
    model = TextEmbeddingModel.from_pretrained("textembedding-gecko@003")
    print("Embedding model initialized.")
    
    embeddings = []
    for idx, text in enumerate(cleaned_text):
        print(f"Embedding text {idx + 1}/{len(cleaned_text)}...")
        input_obj = TextEmbeddingInput(text=text)
        try:
            response = model.get_embeddings([input_obj])
            embedding = response[0].values
            embeddings.append(embedding)
            print(f"Successfully embedded text {idx + 1}")
        except Exception as e:
            print(f"Error embedding text {idx + 1}: {e}")
            embeddings.append(None)

    print("Embedding process completed.")
    
    # Create DataFrame with embeddings
    df_embeddings = pd.DataFrame({
        "text": cleaned_text,
        "embedding": embeddings
    })

    return df_embeddings

# Main function
if __name__ == "__main__":
    # Path to the JSON file created by the collection script
    input_file_path = "aggregated_results_resistant.json"
    print(f"Loading data from {input_file_path}...")

    # Load the JSON file
    with open(input_file_path, "r") as input_file:
        aggregated_results = json.load(input_file)
    
    print(f"Data loaded. Total findings: {len(aggregated_results['findings'])}")
    
    # Clean the findings
    print("Cleaning text data...")
    cleaned_findings = clean_data(aggregated_results["findings"])
    print(f"Cleaned findings: {len(cleaned_findings)} entries remain.")

    # Embed the cleaned text
    print("Embedding text data...")
    embedded_results = embed_text_vertex(cleaned_findings)
    
    # Save the embeddings to a new JSON file
    output_file_path = "embedded_results_nutrition.json"
    embedded_results.to_json(output_file_path, orient="records", indent=4)
    
    print(f"Embedding process completed. Results saved to {output_file_path}.")
